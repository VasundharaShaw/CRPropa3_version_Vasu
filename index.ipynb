# %% [markdown]
# # CRPropa3 Notebook Index
#
# Welcome to the CRPropa3 JupyterHub environment on [Jupyter4NFDI](https://hub.nfdi-jupyter.de/). This notebook is the starting point for exploring cosmic ray propagation simulations. It links to all available example notebooks, both ported from the official CRPropa3 documentation and those developed within this environment.
#
# **New to CRPropa3?** Start with the [Getting Started](#getting-started) check below, then work through the Basics section.
#
# **Looking for a specific module?** Jump to the [Module Reference](#module-reference) at the bottom.
#
# ---
#
# **CRPropa3 version:** 3.2.1 | **Docs:** https://crpropa.github.io/CRPropa3/ | **Source:** https://github.com/CRPropa/CRPropa3 | **Issues:** https://github.com/CRPropa/CRPropa3/issues

# %% [markdown]
# ---
# ## Getting Started <a id='getting-started'></a>
#
# Run the cell below to verify that CRPropa3 is installed correctly in this environment.

# %%
import crpropa
print('CRPropa version:', crpropa.__version__)
print('Data directory:', crpropa.getDataPath())
print('Environment OK!')

# %% [markdown]
# ---
# ## 1. Basics <a id='basics'></a>
#
# Fundamentals of CRPropa3: setting up simulations, defining sources and observers, and writing output.
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [basics](Example_Notebooks/basics/) | Introduction to Python steering: candidates, sources, propagation, observers, output | `ModuleList`, `Candidate`, `Source`, `Observer`, `TextOutput` |
# | [sim1D](Example_Notebooks/sim1D/) | 1D simulation of UHECR propagation with energy losses and secondaries | `SimplePropagation`, `MinimumEnergy`, `Observer1D`, `PhotoPionProduction`, `ElectronPairProduction` |
# | [sim4D](Example_Notebooks/sim4D/) | 4D (3D + energy) simulation with cosmological effects | `PropagationCK`, `FlatgrainRedshift`, `SourceUniformBox` |
#
# **Docs:** [Basic Concepts](https://crpropa.github.io/CRPropa3/pages/Basic-concepts.html) | [Simulation Modules](https://crpropa.github.io/CRPropa3/pages/Simulation-Modules.html)

# %% [markdown]
# ---
# ## 2. Extragalactic Propagation <a id='extragalactic'></a>
#
# Propagation of UHECRs through extragalactic space, including MHD field models and interaction processes.
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [extragalactic_fields](Example_Notebooks/extragalactic_fields/) | 3D MHD field models on uniform grids (CLUES/Hackstein models) | `MagneticFieldGrid`, `VectorGrid`, `loadGrid` |
#
# **Docs:** [Extragalactic Simulations](https://crpropa.github.io/CRPropa3/pages/extragalactic-simulations.html)

# %% [markdown]
# ---
# ## 3. Galactic Propagation <a id='galactic'></a>
#
# Galactic magnetic field models, backtracking, lensing, and trajectory visualization.
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [galactic_backtracking](Example_Notebooks/galactic_backtracking/) | Backtracking cosmic rays through the Galactic magnetic field (JF12); lens generation | `JF12Field`, `PropagationCK`, anti-particle IDs |
# | [galactic_lensing](Example_Notebooks/galactic_lensing/) | Applying magnetic lenses to transform extragalactic arrival directions | `MagneticLens`, `ParticleMapsContainer` |
# | [galactic_trajectories](Example_Notebooks/galactic_trajectories/) | Visualizing cosmic ray trajectories in Galactic fields | `JF12Field`, `PropagationCK`, custom `Module` output |
# | [trajectories](Example_Notebooks/trajectories/) | General trajectory output and visualization | `PropagationCK`, trajectory output |
#
# **Docs:** [Galactic Cosmic Rays](https://crpropa.github.io/CRPropa3/pages/galactic_cosmic_rays.html)

# %% [markdown]
# ---
# ## 4. Diffusion and Acceleration <a id='diffusion'></a>
#
# Ensemble-averaged transport via stochastic differential equations and Fermi acceleration mechanisms.
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [Diffusion](Example_Notebooks/Diffusion/) | Isotropic/anisotropic diffusion (SDE) and momentum diffusion (2nd-order Fermi) | `DiffusionSDE`, `MomentumDiffusion`, `AdvectionField` |
# | [acceleration](Example_Notebooks/acceleration/) | Diffusive shock acceleration (1st-order Fermi) at a planar shock | `DiffusionSDE`, `AdvectionField` |
#
# **Docs:** [Galactic Cosmic Rays (Diffusion)](https://crpropa.github.io/CRPropa3/pages/galactic_cosmic_rays.html)

# %% [markdown]
# ---
# ## 5. Photon and Secondary Emission <a id='secondaries'></a>
#
# Electromagnetic cascades, secondary photon/neutrino production, and custom photon fields.
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [secondaries](Example_Notebooks/secondaries/) | Photon propagation: EM cascades from high-energy photons in background radiation fields | `EMPairProduction`, `EMInverseComptonScattering`, `EMDoublePairProduction` |
# | [photon_propagation](Example_Notebooks/photon_propagation/) | Photon transport and EM cascade development | `EMPairProduction`, `EMInverseComptonScattering` |
# | [custom_photonfields](Example_Notebooks/custom_photonfields/) | Defining and using custom photon background fields | `PhotonField`, `TabularPhotonField` |
#
# **Docs:** [Photon Fields](https://crpropa.github.io/CRPropa3/pages/Photon-Fields.html)

# %% [markdown]
# ---
# ## 6. Density Models and Source Distributions <a id='density'></a>
#
# Galactic gas density distributions and their use in source modelling.
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [density](Example_Notebooks/density/) | Implemented gas density models of the Milky Way (Ferriere, Cordes, Nakanishi) | `Ferriere`, `Cordes`, `Nakanishi` |
#
# **Docs:** [Galactic Density Models](https://crpropa.github.io/CRPropa3/pages/galactic_cosmic_rays.html)

# %% [markdown]
# ---
# ## 7. Advanced Features and Extensions <a id='advanced'></a>
#
# Custom modules, targeting, simulation control, propagation algorithm comparisons, and extending CRPropa3.
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [advanced](Example_Notebooks/advanced/) | Custom observer and module implementations in Python | `ObserverFeature`, custom `Module` subclassing |
# | [targeting](Example_Notebooks/targeting/) | Targeted emission (von-Mises-Fisher distribution) for efficient source-to-observer simulations | `SourceDirectedEmission` |
# | [interrupting_sim](Example_Notebooks/interrupting_sim/) | Interrupting and resuming simulations | `ModuleList` checkpointing |
# | [propagation_comparison](Example_Notebooks/propagation_comparison/) | Comparing propagation algorithms: Boris push vs. Cash-Karp | `PropagationBP`, `PropagationCK` |
# | [extending-CRPropa](Example_Notebooks/extending-CRPropa/) | Writing custom C++ modules and compiling them as plugins | Plugin compilation, SWIG interface |

# %% [markdown]
# ---
# ## 8. In-Environment Notebooks <a id='in-environment'></a>
#
# Notebooks developed within this Jupyter4NFDI environment for specific research and teaching use cases.
#
# | Notebook | Description | Status |
# |---|---|---|
# | Cen A source simulation | Cosmic ray propagation from Centaurus A | Planned |
# | Auger spectrum fit | Fitting the Pierre Auger Observatory energy spectrum using CRDB data | Planned |
# | Turbulent magnetic field comparison | Comparing `initTurbulence` (legacy) with `SimpleGridTurbulence` (modern API) | In progress |

# %% [markdown]
# ---
# ## Module Reference <a id='module-reference'></a>
#
# Quick lookup: find the notebook that demonstrates a given CRPropa3 class or function.
#
# | Module / Class | Notebook(s) |
# |---|---|
# | `ModuleList`, `Candidate`, `Source` | basics |
# | `SimplePropagation`, `MinimumEnergy` | basics, sim1D |
# | `Observer`, `Observer1D`, `ObserverSmallSphere` | basics, sim1D, sim4D |
# | `TextOutput`, `HDF5Output` | basics, sim1D |
# | `PropagationCK` (Cash-Karp) | sim4D, galactic_trajectories, galactic_backtracking, propagation_comparison |
# | `PropagationBP` (Boris Push) | propagation_comparison |
# | `PhotoPionProduction` | sim1D, secondaries |
# | `ElectronPairProduction` | sim1D |
# | `PhotoDisintegration`, `NuclearDecay` | sim1D, sim4D |
# | `EMPairProduction`, `EMInverseComptonScattering` | secondaries, photon_propagation |
# | `JF12Field` | galactic_backtracking, galactic_trajectories |
# | `MagneticFieldGrid`, `VectorGrid`, `loadGrid` | extragalactic_fields |
# | `SimpleGridTurbulence`, `SimpleTurbulenceSpectrum` | (turbulence comparison, in progress) |
# | `MagneticLens`, `ParticleMapsContainer` | galactic_lensing |
# | `DiffusionSDE`, `AdvectionField` | Diffusion, acceleration |
# | `MomentumDiffusion` | Diffusion |
# | `Ferriere`, `Cordes`, `Nakanishi` | density |
# | `TabularPhotonField` | custom_photonfields |
# | `SourceDirectedEmission` | targeting |
# | `crdb` (Python package) | (Auger spectrum fit, planned) |

# %% [markdown]
# ---
# ## External Resources
#
# - **CRPropa3 documentation:** https://crpropa.github.io/CRPropa3/
# - **CRPropa3 GitHub:** https://github.com/CRPropa/CRPropa3
# - **CRPropa3 example notebooks (source):** https://github.com/CRPropa/CRPropa3/tree/master/doc/pages/example_notebooks
# - **Cosmic Ray Database (CRDB):** https://crdb.unistra.fr/
# - **Jupyter4NFDI:** https://nfdi-jupyter.de/
# - **This environment:** https://hub.nfdi-jupyter.de/
# - **CRPropa3 citation:** R. Alves Batista et al., JCAP (2022) no. 09, 035; [arXiv:2208.00107](https://arxiv.org/abs/2208.00107)

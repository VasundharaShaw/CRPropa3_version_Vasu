# %% [markdown]
# # CRPropa3 Notebook Index
#
# Welcome to the CRPropa3 JupyterHub environment on [Jupyter4NFDI](https://hub.nfdi-jupyter.de/). This notebook is the starting point for exploring cosmic ray propagation simulations. It links to all available example notebooks, both ported from the official CRPropa3 documentation and those developed within this environment.
#
# **New to CRPropa3?** Start with the [Getting Started](#getting-started) check below, then work through the Basics section.
#
# **Looking for a specific module?** Jump to the [Module Reference](#module-reference) at the bottom.
#
# ---
#
# **CRPropa3 version:** 3.2.1 | **Docs:** https://crpropa.github.io/CRPropa3/ | **Source:** https://github.com/CRPropa/CRPropa3 | **Issues:** https://github.com/CRPropa/CRPropa3/issues

# %% [markdown]
# ---
# ## Getting Started <a id='getting-started'></a>
#
# Run the cell below to verify that CRPropa3 is installed correctly in this environment.

# %%
import crpropa
print('CRPropa version:', crpropa.__version__)
print('Data directory:', crpropa.getDataPath())
print('Environment OK!')

# %% [markdown]
# ---
# ## 1. Basics <a id='basics'></a>
#
# Fundamentals of CRPropa3: setting up simulations, defining sources and observers, and writing output.
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [basics.ipynb](Example_Notebooks/basics/basics.ipynb) | Introduction to Python steering: candidates, sources, propagation, observers, output | `ModuleList`, `Candidate`, `Source`, `Observer`, `TextOutput` |
# | [sim1D.ipynb](Example_Notebooks/sim1D/sim1D.ipynb) | 1D simulation of UHECR propagation with energy losses and secondaries | `SimplePropagation`, `MinimumEnergy`, `Observer1D`, `PhotoPionProduction`, `ElectronPairProduction` |
# | [sim4D.ipynb](Example_Notebooks/sim4D/sim4D.ipynb) | 4D (3D + energy) simulation with cosmological effects | `PropagationCK`, `FlatgrainRedshift`, `SourceUniformBox` |
#
# **Docs:** [Basic Concepts](https://crpropa.github.io/CRPropa3/pages/Basic-concepts.html) | [Simulation Modules](https://crpropa.github.io/CRPropa3/pages/Simulation-Modules.html)

# %% [markdown]
# ---
# ## 2. Extragalactic Propagation <a id='extragalactic'></a>
#
# Propagation of UHECRs through extragalactic space, including MHD field models and interaction processes.
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [MHD_models.ipynb](Example_Notebooks/extragalactic_fields/MHD_models.ipynb) | 3D MHD field models on uniform grids (CLUES/Hackstein models) | `MagneticFieldGrid`, `VectorGrid`, `loadGrid` |
#
# **Docs:** [Extragalactic Simulations](https://crpropa.github.io/CRPropa3/pages/extragalactic-simulations.html)

# %% [markdown]
# ---
# ## 3. Galactic Propagation <a id='galactic'></a>
#
# Galactic magnetic field models, backtracking, lensing, and trajectory visualization.
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [galactic_backtracking.ipynb](Example_Notebooks/galactic_backtracking/galactic_backtracking.ipynb) | Backtracking cosmic rays through the Galactic magnetic field (JF12); lens generation | `JF12Field`, `PropagationCK`, anti-particle IDs |
# | [lensing_cr.ipynb](Example_Notebooks/galactic_lensing/lensing_cr.ipynb) | Applying magnetic lenses to transform extragalactic arrival directions | `MagneticLens`, `ParticleMapsContainer` |
# | [galactic_trajectories.ipynb](Example_Notebooks/galactic_trajectories/galactic_trajectories.ipynb) | Visualizing cosmic ray trajectories in Galactic fields | `JF12Field`, `PropagationCK`, custom `Module` output |
# | [trajectories.ipynb](Example_Notebooks/trajectories/trajectories.ipynb) | General trajectory output and visualization | `PropagationCK`, trajectory output |
#
# **Docs:** [Galactic Cosmic Rays](https://crpropa.github.io/CRPropa3/pages/galactic_cosmic_rays.html)

# %% [markdown]
# ---
# ## 4. Diffusion and Acceleration <a id='diffusion'></a>
#
# Ensemble-averaged transport via stochastic differential equations and Fermi acceleration mechanisms.
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [DiffusionValidationI.ipynb](Example_Notebooks/Diffusion/DiffusionValidationI.ipynb) | Isotropic and anisotropic diffusion validation (SDE) | `DiffusionSDE`, `AdvectionField` |
# | [MomentumDiffusion.ipynb](Example_Notebooks/Diffusion/MomentumDiffusion.ipynb) | Second-order Fermi (momentum diffusion / stochastic acceleration) | `MomentumDiffusion` |
# | [AdiabaticCooling.ipynb](Example_Notebooks/Diffusion/AdiabaticCooling.ipynb) | Adiabatic cooling in a spherical advection field | `DiffusionSDE`, `AdiabaticCooling`, `ConstantSphericalAdvectionField` |
# | [acceleration.ipynb](Example_Notebooks/acceleration/acceleration.ipynb) | Diffusive shock acceleration (1st-order Fermi) at a planar shock | `DiffusionSDE`, `AdvectionField` |
#
# **Docs:** [Galactic Cosmic Rays (Diffusion)](https://crpropa.github.io/CRPropa3/pages/galactic_cosmic_rays.html)

# %% [markdown]
# ---
# ## 5. Photon and Secondary Emission <a id='secondaries'></a>
#
# Electromagnetic cascades, secondary photon/neutrino production, and custom photon fields.
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [photons.ipynb](Example_Notebooks/secondaries/photons.ipynb) | Photon propagation: EM cascades in background radiation fields, photons from proton propagation | `EMPairProduction`, `EMInverseComptonScattering`, `EMDoublePairProduction` |
# | [photon_propagation.ipynb](Example_Notebooks/photon_propagation/photon_propagation.ipynb) | Photon transport and EM cascade development | `EMPairProduction`, `EMInverseComptonScattering` |
# | [custom-photon-field.ipynb](Example_Notebooks/custom_photonfields/custom-photon-field.ipynb) | Defining and using custom photon background fields | `PhotonField`, `TabularPhotonField` |
#
# **Docs:** [Photon Fields](https://crpropa.github.io/CRPropa3/pages/Photon-Fields.html)

# %% [markdown]
# ---
# ## 6. Density Models and Source Distributions <a id='density'></a>
#
# Galactic gas density distributions and their use in source modelling.
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [densitys_model_example.ipynb](Example_Notebooks/density/densitys_model_example.ipynb) | Implemented gas density models of the Milky Way (Ferriere, Cordes, Nakanishi) | `Ferriere`, `Cordes`, `Nakanishi` |
#
# **Docs:** [Galactic Density Models](https://crpropa.github.io/CRPropa3/pages/galactic_cosmic_rays.html)

# %% [markdown]
# ---
# ## 7. Advanced Features and Extensions <a id='advanced'></a>
#
# Custom modules, targeting, simulation control, propagation algorithm comparisons, and extending CRPropa3.
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [CustomObserver.ipynb](Example_Notebooks/advanced/CustomObserver.ipynb) | Custom observer and module implementations in Python | `ObserverFeature`, custom `Module` subclassing |
# | [Propagation_Comparison_CK_BP.ipynb](Example_Notebooks/propagation_comparison/Propagation_Comparison_CK_BP.ipynb) | Comparing propagation algorithms: Boris push vs. Cash-Karp | `PropagationBP`, `PropagationCK` |
# | [targeting.ipynb](Example_Notebooks/targeting/targeting.ipynb) | Targeted emission (von-Mises-Fisher distribution) for efficient source-to-observer simulations | `SourceDirectedEmission` |
# | [interrupting_sim.ipynb](Example_Notebooks/interrupting_sim/interrupting_sim.ipynb) | Interrupting and resuming simulations | `ModuleList` checkpointing |
# | [extending-CRPropa.ipynb](Example_Notebooks/extending-CRPropa/extending-CRPropa.ipynb) | Writing custom C++ modules and compiling them as plugins | Plugin compilation, SWIG interface |

# %% [markdown]
# ---
# ## 8. In-Environment Notebooks <a id='in-environment'></a>
#
# Notebooks developed within this Jupyter4NFDI environment for specific research and teaching use cases.
#
# | Notebook | Description | Status |
# |---|---|---|
# | [CenA_potential_Source.ipynb](Example_Notebooks/CenA_source/CenA_potential_Source.ipynb) | Cosmic ray propagation from Centaurus A | Implemented|
# | Auger spectrum fit | Fitting the Pierre Auger Observatory energy spectrum using CRDB data | Planned |
# | Turbulent magnetic field comparison | Comparing `initTurbulence` (legacy) with `SimpleGridTurbulence` (modern API) | In progress |

# %% [markdown]
# ---
# ## Module Reference <a id='module-reference'></a>
#
# Quick lookup: find the notebook that demonstrates a given CRPropa3 class or function.
#
# | Module / Class | Notebook(s) |
# |---|---|
# | `ModuleList`, `Candidate`, `Source` | basics.ipynb |
# | `SimplePropagation`, `MinimumEnergy` | basics.ipynb, sim1D.ipynb |
# | `Observer`, `Observer1D`, `ObserverSmallSphere` | basics.ipynb, sim1D.ipynb, sim4D.ipynb |
# | `TextOutput`, `HDF5Output` | basics.ipynb, sim1D.ipynb |
# | `PropagationCK` (Cash-Karp) | sim4D.ipynb, galactic_trajectories.ipynb, galactic_backtracking.ipynb, Propagation_Comparison_CK_BP.ipynb |
# | `PropagationBP` (Boris Push) | Propagation_Comparison_CK_BP.ipynb |
# | `PhotoPionProduction` | sim1D.ipynb, photons.ipynb |
# | `ElectronPairProduction` | sim1D.ipynb |
# | `PhotoDisintegration`, `NuclearDecay` | sim1D.ipynb, sim4D.ipynb |
# | `EMPairProduction`, `EMInverseComptonScattering` | photons.ipynb, photon_propagation.ipynb |
# | `JF12Field` | galactic_backtracking.ipynb, galactic_trajectories.ipynb |
# | `MagneticFieldGrid`, `VectorGrid`, `loadGrid` | MHD_models.ipynb |
# | `SimpleGridTurbulence`, `SimpleTurbulenceSpectrum` | (turbulence comparison, in progress) |
# | `MagneticLens`, `ParticleMapsContainer` | lensing_cr.ipynb |
# | `DiffusionSDE`, `AdvectionField` | DiffusionValidationI.ipynb, acceleration.ipynb |
# | `MomentumDiffusion` | MomentumDiffusion.ipynb |
# | `AdiabaticCooling` | AdiabaticCooling.ipynb |
# | `Ferriere`, `Cordes`, `Nakanishi` | densitys_model_example.ipynb |
# | `TabularPhotonField` | custom-photon-field.ipynb |
# | `SourceDirectedEmission` | targeting.ipynb |
# | `crdb` (Python package) | (Auger spectrum fit, planned) |

# %% [markdown]
# ---
# ## External Resources
#
# - **CRPropa3 documentation:** https://crpropa.github.io/CRPropa3/
# - **CRPropa3 GitHub:** https://github.com/CRPropa/CRPropa3
# - **CRPropa3 example notebooks (source):** https://github.com/CRPropa/CRPropa3/tree/master/doc/pages/example_notebooks
# - **Cosmic Ray Database (CRDB):** https://crdb.unistra.fr/
# - **Jupyter4NFDI:** https://nfdi-jupyter.de/
# - **This environment:** https://hub.nfdi-jupyter.de/
# - **CRPropa3 citation:** R. Alves Batista et al., JCAP (2022) no. 09, 035; [arXiv:2208.00107](https://arxiv.org/abs/2208.00107)

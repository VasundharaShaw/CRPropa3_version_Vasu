# %% [markdown]
# <div style="background: linear-gradient(135deg, #0f2027 0%, #1a3a4a 50%, #0f2027 100%); border-radius: 12px; padding: 36px 40px 28px 40px; margin-bottom: 8px; box-shadow: 0 4px 32px rgba(0,0,0,0.35);">
#   <div style="display:flex; align-items:center; gap:16px; margin-bottom:12px;">
#     <span style="font-size:2.6rem;">☄️</span>
#     <h1 style="margin:0; font-family:'Georgia', serif; font-size:2.1rem; color:#f0f4f8; letter-spacing:-0.5px;">CRPropa3 Notebook Index</h1>
#   </div>
#   <p style="margin:0 0 18px 0; color:#a8c8d8; font-size:1.05rem; line-height:1.6; max-width:800px;">
#     Welcome to the CRPropa3 JupyterHub environment on <a href='https://hub.nfdi-jupyter.de/' style='color:#5bc8f5;'>Jupyter4NFDI</a>. This notebook is the starting point for exploring cosmic ray propagation simulations — linking to all available examples, both ported from official documentation and developed within this environment.
#   </p>
#   <div style="display:flex; flex-wrap:wrap; gap:10px; margin-bottom:18px;">
#     <a href='https://crpropa.github.io/CRPropa3/' style="background:#1e4d6b; color:#7dd3f8; padding:5px 14px; border-radius:20px; font-size:0.82rem; text-decoration:none; font-family:monospace;">📖 Docs</a>
#     <a href='https://github.com/CRPropa/CRPropa3' style="background:#1e4d6b; color:#7dd3f8; padding:5px 14px; border-radius:20px; font-size:0.82rem; text-decoration:none; font-family:monospace;">⚙ GitHub</a>
#     <a href='https://github.com/CRPropa/CRPropa3/issues' style="background:#1e4d6b; color:#7dd3f8; padding:5px 14px; border-radius:20px; font-size:0.82rem; text-decoration:none; font-family:monospace;">🐛 Issues</a>
#     <span style="background:#2a3f2a; color:#7dcc8a; padding:5px 14px; border-radius:20px; font-size:0.82rem; font-family:monospace;">v3.2.1</span>
#   </div>
#   <div style="background:rgba(255,255,255,0.05); border-left:3px solid #5bc8f5; border-radius:0 8px 8px 0; padding:10px 16px;">
#     <span style="color:#c8e6f5; font-size:0.92rem;">💡 <b>New here?</b> Start with the <a href='#getting-started' style='color:#5bc8f5;'>Getting Started</a> check below, then work through the Basics section.</span>
#   </div>
# </div>

# %% [markdown]
# <h2 id='getting-started' style="font-family:'Georgia',serif; color:#1a3a4a; border-bottom:2px solid #5bc8f5; padding-bottom:6px; margin-top:28px;">🚀 Getting Started</h2>
#
# Run the cell below to verify that CRPropa3 is installed correctly in this environment.

# %%
import crpropa
print('Environment OK!')
# Out:
# Environment OK!

# %% [markdown]
# <h2 id='basics' style="font-family:'Georgia',serif; color:#1a3a4a; border-bottom:2px solid #5bc8f5; padding-bottom:6px; margin-top:28px;">1. Basics</h2>
#
# <p style="color:#444; margin-bottom:12px;">Fundamentals of CRPropa3: setting up simulations, defining sources and observers, and writing output.</p>
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [basics.ipynb](Example_Notebooks/basics/basics.ipynb) | Introduction to Python steering: candidates, sources, propagation, observers, output | `ModuleList`, `Candidate`, `Source`, `Observer`, `TextOutput` |
# | [sim1D.ipynb](Example_Notebooks/sim1D/sim1D.ipynb) | 1D simulation of UHECR propagation with energy losses and secondaries | `SimplePropagation`, `MinimumEnergy`, `Observer1D`, `PhotoPionProduction`, `ElectronPairProduction` |
# | [sim4D.ipynb](Example_Notebooks/sim4D/sim4D.ipynb) | 4D (3D + energy) simulation with cosmological effects | `PropagationCK`, `FlatgrainRedshift`, `SourceUniformBox` |
#
# <p style="margin-top:8px;">📚 <b>Docs:</b> <a href='https://crpropa.github.io/CRPropa3/pages/Basic-concepts.html'>Basic Concepts</a> &nbsp;|&nbsp; <a href='https://crpropa.github.io/CRPropa3/pages/Simulation-Modules.html'>Simulation Modules</a></p>

# %% [markdown]
# <h2 id='extragalactic' style="font-family:'Georgia',serif; color:#1a3a4a; border-bottom:2px solid #5bc8f5; padding-bottom:6px; margin-top:28px;">2. Extragalactic Propagation</h2>
#
# <p style="color:#444; margin-bottom:12px;">Propagation of UHECRs through extragalactic space, including MHD field models and interaction processes.</p>
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [MHD_models.ipynb](Example_Notebooks/extragalactic_fields/MHD_models.ipynb) | 3D MHD field models on uniform grids (CLUES/Hackstein models) | `MagneticFieldGrid`, `VectorGrid`, `loadGrid` |
#
# <p style="margin-top:8px;">📚 <b>Docs:</b> <a href='https://crpropa.github.io/CRPropa3/pages/extragalactic-simulations.html'>Extragalactic Simulations</a></p>

# %% [markdown]
# <h2 id='galactic' style="font-family:'Georgia',serif; color:#1a3a4a; border-bottom:2px solid #5bc8f5; padding-bottom:6px; margin-top:28px;">3. Galactic Propagation</h2>
#
# <p style="color:#444; margin-bottom:12px;">Galactic magnetic field models, backtracking, lensing, and trajectory visualization.</p>
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [galactic_backtracking.ipynb](Example_Notebooks/galactic_backtracking/galactic_backtracking.ipynb) | Backtracking cosmic rays through the Galactic magnetic field (JF12); lens generation | `JF12Field`, `PropagationCK`, anti-particle IDs |
# | [lensing_cr.ipynb](Example_Notebooks/galactic_lensing/lensing_cr.ipynb) | Applying magnetic lenses to transform extragalactic arrival directions | `MagneticLens`, `ParticleMapsContainer` |
# | [galactic_trajectories.ipynb](Example_Notebooks/galactic_trajectories/galactic_trajectories.ipynb) | Visualizing cosmic ray trajectories in Galactic fields | `JF12Field`, `PropagationCK`, custom `Module` output |
# | [trajectories.ipynb](Example_Notebooks/trajectories/trajectories.ipynb) | General trajectory output and visualization | `PropagationCK`, trajectory output |
#
# <p style="margin-top:8px;">📚 <b>Docs:</b> <a href='https://crpropa.github.io/CRPropa3/pages/galactic_cosmic_rays.html'>Galactic Cosmic Rays</a></p>

# %% [markdown]
# <h2 id='diffusion' style="font-family:'Georgia',serif; color:#1a3a4a; border-bottom:2px solid #5bc8f5; padding-bottom:6px; margin-top:28px;">4. Diffusion and Acceleration</h2>
#
# <p style="color:#444; margin-bottom:12px;">Ensemble-averaged transport via stochastic differential equations and Fermi acceleration mechanisms.</p>
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [DiffusionValidationI.ipynb](Example_Notebooks/Diffusion/DiffusionValidationI.ipynb) | Isotropic and anisotropic diffusion validation (SDE) | `DiffusionSDE`, `AdvectionField` |
# | [MomentumDiffusion.ipynb](Example_Notebooks/Diffusion/MomentumDiffusion.ipynb) | Second-order Fermi (momentum diffusion / stochastic acceleration) | `MomentumDiffusion` |
# | [AdiabaticCooling.ipynb](Example_Notebooks/Diffusion/AdiabaticCooling.ipynb) | Adiabatic cooling in a spherical advection field | `DiffusionSDE`, `AdiabaticCooling`, `ConstantSphericalAdvectionField` |
# | [acceleration.ipynb](Example_Notebooks/acceleration/acceleration.ipynb) | Diffusive shock acceleration (1st-order Fermi) at a planar shock | `DiffusionSDE`, `AdvectionField` |
#
# <p style="margin-top:8px;">📚 <b>Docs:</b> <a href='https://crpropa.github.io/CRPropa3/pages/galactic_cosmic_rays.html'>Galactic Cosmic Rays (Diffusion)</a></p>

# %% [markdown]
# <h2 id='secondaries' style="font-family:'Georgia',serif; color:#1a3a4a; border-bottom:2px solid #5bc8f5; padding-bottom:6px; margin-top:28px;">5. Photon and Secondary Emission</h2>
#
# <p style="color:#444; margin-bottom:12px;">Electromagnetic cascades, secondary photon/neutrino production, and custom photon fields.</p>
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [photons.ipynb](Example_Notebooks/secondaries/photons.ipynb) | Photon propagation: EM cascades in background radiation fields, photons from proton propagation | `EMPairProduction`, `EMInverseComptonScattering`, `EMDoublePairProduction` |
# | [photon_propagation.ipynb](Example_Notebooks/photon_propagation/photon_propagation.ipynb) | Photon transport and EM cascade development | `EMPairProduction`, `EMInverseComptonScattering` |
# | [custom-photon-field.ipynb](Example_Notebooks/custom_photonfields/custom-photon-field.ipynb) | Defining and using custom photon background fields | `PhotonField`, `TabularPhotonField` |
#
# <p style="margin-top:8px;">📚 <b>Docs:</b> <a href='https://crpropa.github.io/CRPropa3/pages/Photon-Fields.html'>Photon Fields</a></p>

# %% [markdown]
# <h2 id='density' style="font-family:'Georgia',serif; color:#1a3a4a; border-bottom:2px solid #5bc8f5; padding-bottom:6px; margin-top:28px;">6. Density Models and Source Distributions</h2>
#
# <p style="color:#444; margin-bottom:12px;">Galactic gas density distributions and their use in source modelling.</p>
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [densitys_model_example.ipynb](Example_Notebooks/density/densitys_model_example.ipynb) | Implemented gas density models of the Milky Way (Ferriere, Cordes, Nakanishi) | `Ferriere`, `Cordes`, `Nakanishi` |
#
# <p style="margin-top:8px;">📚 <b>Docs:</b> <a href='https://crpropa.github.io/CRPropa3/pages/galactic_cosmic_rays.html'>Galactic Density Models</a></p>

# %% [markdown]
# <h2 id='advanced' style="font-family:'Georgia',serif; color:#1a3a4a; border-bottom:2px solid #5bc8f5; padding-bottom:6px; margin-top:28px;">7. Advanced Features and Extensions</h2>
#
# <p style="color:#444; margin-bottom:12px;">Custom modules, targeting, simulation control, propagation algorithm comparisons, and extending CRPropa3.</p>
#
# | Notebook | Description | Key Modules |
# |---|---|---|
# | [CustomObserver.ipynb](Example_Notebooks/advanced/CustomObserver.ipynb) | Custom observer and module implementations in Python | `ObserverFeature`, custom `Module` subclassing |
# | [Propagation_Comparison_CK_BP.ipynb](Example_Notebooks/propagation_comparison/Propagation_Comparison_CK_BP.ipynb) | Comparing propagation algorithms: Boris push vs. Cash-Karp | `PropagationBP`, `PropagationCK` |
# | [targeting.ipynb](Example_Notebooks/targeting/targeting.ipynb) | Targeted emission (von-Mises-Fisher distribution) for efficient source-to-observer simulations | `SourceDirectedEmission` |
# | [interrupting_sim.ipynb](Example_Notebooks/interrupting_sim/interrupting_sim.ipynb) | Interrupting and resuming simulations | `ModuleList` checkpointing |
# | [extending-CRPropa.ipynb](Example_Notebooks/extending-CRPropa/extending-CRPropa.ipynb) | Writing custom C++ modules and compiling them as plugins | Plugin compilation, SWIG interface |

# %% [markdown]
# <h2 id='in-environment' style="font-family:'Georgia',serif; color:#1a3a4a; border-bottom:2px solid #e8a020; padding-bottom:6px; margin-top:28px;">8. In-Environment Notebooks ⭐</h2>
#
# <p style="color:#444; margin-bottom:12px;">Notebooks developed within this Jupyter4NFDI environment for specific research and teaching use cases.</p>
#
# | Notebook | Description | Status |
# |---|---|---|
# | [CenA_potential_Source.ipynb](Example_Notebooks/CenA_source/CenA_potential_Source.ipynb) | Cosmic ray propagation from Centaurus A | ✅ Implemented |
# | Auger spectrum fit | Fitting the Pierre Auger Observatory energy spectrum using CRDB data | 🔲 Planned |
# | Turbulent magnetic field comparison | Comparing `initTurbulence` (legacy) with `SimpleGridTurbulence` (modern API) | 🔄 In progress |

# %% [markdown]
# <h2 id='module-reference' style="font-family:'Georgia',serif; color:#1a3a4a; border-bottom:2px solid #5bc8f5; padding-bottom:6px; margin-top:28px;">🔍 Module Reference</h2>
#
# <p style="color:#444; margin-bottom:12px;">Quick lookup: find the notebook that demonstrates a given CRPropa3 class or function.</p>
#
# | Module / Class | Notebook(s) |
# |---|---|
# | `ModuleList`, `Candidate`, `Source` | basics.ipynb |
# | `SimplePropagation`, `MinimumEnergy` | basics.ipynb, sim1D.ipynb |
# | `Observer`, `Observer1D`, `ObserverSmallSphere` | basics.ipynb, sim1D.ipynb, sim4D.ipynb |
# | `TextOutput`, `HDF5Output` | basics.ipynb, sim1D.ipynb |
# | `PropagationCK` (Cash-Karp) | sim4D.ipynb, galactic_trajectories.ipynb, galactic_backtracking.ipynb, Propagation_Comparison_CK_BP.ipynb |
# | `PropagationBP` (Boris Push) | Propagation_Comparison_CK_BP.ipynb |
# | `PhotoPionProduction` | sim1D.ipynb, photons.ipynb |
# | `ElectronPairProduction` | sim1D.ipynb |
# | `PhotoDisintegration`, `NuclearDecay` | sim1D.ipynb, sim4D.ipynb |
# | `EMPairProduction`, `EMInverseComptonScattering` | photons.ipynb, photon_propagation.ipynb |
# | `JF12Field` | galactic_backtracking.ipynb, galactic_trajectories.ipynb |
# | `MagneticFieldGrid`, `VectorGrid`, `loadGrid` | MHD_models.ipynb |
# | `SimpleGridTurbulence`, `SimpleTurbulenceSpectrum` | (turbulence comparison, in progress) |
# | `MagneticLens`, `ParticleMapsContainer` | lensing_cr.ipynb |
# | `DiffusionSDE`, `AdvectionField` | DiffusionValidationI.ipynb, acceleration.ipynb |
# | `MomentumDiffusion` | MomentumDiffusion.ipynb |
# | `AdiabaticCooling` | AdiabaticCooling.ipynb |
# | `Ferriere`, `Cordes`, `Nakanishi` | densitys_model_example.ipynb |
# | `TabularPhotonField` | custom-photon-field.ipynb |
# | `SourceDirectedEmission` | targeting.ipynb |
# | `crdb` (Python package) | (Auger spectrum fit, planned) |

# %% [markdown]
# <div style="background:#f0f7ff; border:1px solid #c8dff5; border-radius:10px; padding:20px 28px; margin-top:28px;">
#   <h2 style="font-family:'Georgia',serif; color:#1a3a4a; margin-top:0; margin-bottom:14px;">🌐 External Resources</h2>
#   <ul style="list-style:none; padding:0; margin:0; line-height:2.1;">
#     <li>📖 <b>CRPropa3 documentation:</b> <a href='https://crpropa.github.io/CRPropa3/'>crpropa.github.io/CRPropa3</a></li>
#     <li>⚙ <b>CRPropa3 GitHub:</b> <a href='https://github.com/CRPropa/CRPropa3'>github.com/CRPropa/CRPropa3</a></li>
#     <li>📓 <b>Official example notebooks:</b> <a href='https://github.com/CRPropa/CRPropa3/tree/master/doc/pages/example_notebooks'>doc/pages/example_notebooks</a></li>
#     <li>🗄 <b>Cosmic Ray Database (CRDB):</b> <a href='https://crdb.unistra.fr/'>crdb.unistra.fr</a></li>
#     <li>🖥 <b>Jupyter4NFDI:</b> <a href='https://nfdi-jupyter.de/'>nfdi-jupyter.de</a> &nbsp;|&nbsp; <b>This environment:</b> <a href='https://hub.nfdi-jupyter.de/'>hub.nfdi-jupyter.de</a></li>
#     <li>📄 <b>CRPropa3 citation:</b> R. Alves Batista et al., JCAP (2022) no. 09, 035 &nbsp;<a href='https://arxiv.org/abs/2208.00107'>[arXiv:2208.00107]</a></li>
#   </ul>
# </div>
